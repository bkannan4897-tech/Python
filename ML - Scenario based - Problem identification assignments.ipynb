# %% [markdown]
#                                                     Hope Artificial Intelligence
#                                                        Scenario Based Learning
#
# Question:
#
# A company works with number of employees, all the works are dependents on the employees. Even
# if one of the employees resign the job immediately then assigned work will be not finished at the
# time, so delivery of the project to the clients will be delayed. Company planned to make solution for
# this, they want to know which employee may resign next. If they know previously, they can arrange
# alternative to avoid such problem. As an AI Engineer you must give Solution to this.
#
# A) How will you achieve this in AI?
# B) Find out the 3 -Stage of Problem Identification
# C) Name the project
# D) Create the dummy Dataset.
#
#
# Answer:
#
# A) How will you achieve this in AI?
#
# Identify the problem, Why the one of the employee resign the job immediately, analys the data of the resigned employee and list out the reasons like
#                     1.Salary increment
#                     2.Promotion
#                     3.One branch to another branch tranfer
#                     4.Health issues
#                     5.Take care of their old age parents
#                     6.Starting own business
#                     7.Over pressure
#                     8.Clashes between team leader or project manager
#                     9.Passionate other than a job
#                     10.Over time working
#                     11.Parenting - Take care of their child
#
# so, with the same problems or some other problems may have for other employees in the company. Take survey and give a data to the AI. AI will analys the data and predict who will be resign next.
#
#
# B) Find out the 3 -Stage of Problem Identification
#
# Stage 1 - Natural language processing (Text format)
# Stage 2 - Unsupervised learning (No proper input)
# Stage 3 - Classification (Categorical value)
#
#
# C) Name the project
#
# Next employee job resign - AI Prediction
#
#
# D) Create the dummy Dataset
#
# R.no       Name       Department                      Problem
# 1.       Karthick     Software - Developer            salary increment
# 2.       Balaji       Software - Testing              Passionate other than job
# 3.       Sowmiya      Marketing                       Parenting - Take care of their child
# 4.       Raja         Software - Developer            Over pressure
# 5.       Vels         Cloud                           Health issues
# 6.       Pooja        AI - Developer                  Over time working
