# %% [markdown]
#                                                     Hope Artificial Intelligence
#                                                        Scenario-Based Learning
#
# Question:
#
# A company works with number of employees, all the works are dependents on the employees. Even
# if one of the employees resign the job immediately then assigned work will be not finished at the
# time, so delivery of the project to the clients will be delayed. Company planned to make solution for
# this, they want to know which employee may resign next. If they know previously, they can arrange
# alternative to avoid such problem. As an AI Engineer you must give Solution to this.
#
# A) How will you achieve this in AI?
# B) Find out the 3 -Stage of Problem Identification
# C) Name the project
# D) Create the dummy Dataset.
#
#
# Answer:
#
# A) How will you achieve this in AI?
#
# Identify the problem, why one of the employees resigned from the job immediately, analyse the data of the resigned employee and list out the reasons like
#                     1. Salary increment
#                     2. Promotion
#                     3. One branch to another branch transfer
#                     4. Health issues
#                     5. Take care of their old-age parents
#                     6. Starting own business
#                     7. Overpressure
#                     8. Clashes between the team leader or project manager
#                     9. Passionate about something other than a job
#                     10. Over time, working
#                     11. Parenting - Take care of their child
#
# So, with the same problems or some other problems that other employees in the company have. Give data to the AI. AI will analyse the data and predict who will resign next.
#
#
# B) Find out the 3 stages of Problem Identification
#
# Stage 1 - Machine learning
# Stage 2 - Supervised learning (Requirement and Input, output data is clear)
# Stage 3 - Classification (Categorical value)
#
#
# C) Name the project
#
# Next employee job resignation - AI Prediction
#
#
# D) Create the dummy Dataset
#
# R.no       Name       Department                      Problem                                     Age         Output
# 1.       Karthick     Software - Developer            salary increment                            30          Resigned
# 2.       Balaji       Software - Testing              Passionate other than job                   27          Not Resigned
# 3.       Sowmiya      Marketing                       Parenting - Take care of their child        26          Resigned
# 4.       Raja         Software - Developer            Overpressure                                45          Resigned
# 5.       Vels         Cloud                           Health issues                               48          Not resigned
# 6.       Pooja        AI - Developer                  Over time, working                          35          Resigned
