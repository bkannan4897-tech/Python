# %%
if(Condition):
    print()
else:  
    print()

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 18

# %%
if(age<18):
    print("Children")
else:
    print("Adult")
# Out:
# Adult

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 10

# %%
if(age<18):
    print("Children")
else:
    print("Adult")
# Out:
# Children
