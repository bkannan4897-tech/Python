# %%
#Function Syntax

# %%
#Addition

# %%
def addition (a,b):
    addition = a+b
    return addition

# %%
#Subtraction

# %%
def subtraction (a,b):
    sub = a-b
    return sub

# %%
#Multiplication

# %%
def Multiplication (a,b):
    Mul = a*b
    return Mul
