# %%
#OOPS - Class Syntax

# %%
class calculator():
    def Addition(a,b):
        Addition=a+b
        return Addition

    def Subtraction(a,b):
        Subtraction=a-b
        return Subtraction

    def Multiplication(a*b):
        Mul=a*b
        return Mul
