# %%
#Syntax - Machine learning - Multiple linear regression - Phase 2 - AI Model Deployment

# %%
import pickle #Pickle is a library

# %%
loaded_model=pickle.load(open("finalized_model_Multiple_linear.sav",'rb'))
result=loaded_model.predict([[165349.20,136897.80,471784.10,0,1]]) # Department-wise investment and predict Profit - AI model for Profit Prediction.
# Investment like R&D, Administration, Marketing spend, State_florida, State_Newyork
# Out:
# C:\Users\bkann\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[192239.66787833]])
