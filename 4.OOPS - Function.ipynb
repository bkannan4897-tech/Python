# %%
#Method 1

# %%
Lists=[23,45,67,34,89]

# %%
def Agecategory():
    for age in Lists:
        if(age<18):
            print("Children")
        elif(age<35):
            print("Adult")
        elif(age<59):
            print("Citizen")
        else:
            print("Senior Citizen")

# %%
 Agecategory()
# Out:
# Adult
# Citizen
# Senior Citizen
# Adult
# Senior Citizen

# %%
#Method 2

# %%
age=int(input("Enter the Age:"))
# Out:
# Enter the Age: 45

# %%
def Agecategory():
        if(Age<18):
            print("Children")
            cate="Children"
        elif(Age<35):
            print("Adult")
            cate="Adult"
        elif(Age<59):
            print("Citizen")
            cate="Citizen"
        else:
            print("Senior Citizen")
            cate="Senior Citizen"
        return cate

# %%
Agecategory()
# Out:
# Citizen
# 'Citizen'

# %%
Agecate=Agecategory()
# Out:
# Citizen

# %%
Agecate
# Out:
# 'Citizen'

# %%
#Method 3

# %%
def Agecategory():
        if(Age<18):
            print("Children")
            cate="Children"
        elif(Age<35):
            print("Adult")
            cate="Adult"
        elif(Age<59):
            print("Citizen")
            cate="Citizen"
        else:
            print("Senior Citizen")
            cate="Senior Citizen"
        return cate

# %%
Age=int(input("Enter the Age:"))
agecate=Agecategory()
# Out:
# Enter the Age: 25
# Adult

# %%
print(agecate)
# Out:
# Adult

# %%
#Method 4

# %%
def AgecategoryNoR():
        if(Age<18):
            print("Children")
            cate="Children"
        elif(Age<35):
            print("Adult")
            cate="Adult"
        elif(Age<59):
            print("Citizen")
            cate="Citizen"
        else:
            print("Senior Citizen")
            cate="Senior Citizen"

# %%
Age=int(input("Enter the Age:"))
agecate=AgecategoryNoR()
# Out:
# Enter the Age: 10
# Children

# %%
print(agecate)
# Out:
# None

# %%
Age=int(input("Enter the Age:"))
agecate1=Agecategory()
# Out:
# Enter the Age: 67
# Senior Citizen

# %%
#Odd or Even - Method 5

# %%
def oddEven():
    num=int(input("Enter the Number:"))
    if((num%2)==1):
        print("Odd Number")
        message="Odd Number"
    else:
        print("Even Number")
        message="Even Number"
    return message

# %%
message=oddEven()
# Out:
# Enter the Number: 5
# Odd Number

# %%
if(message=="Even Number"):
    print("The Given Number is Even")
else:
    print("The Given Number is Odd")
# Out:
# The Given Number is Odd

# %%
#Body Mass Index - Method 6

# %%
def BMI():
    BMI=float(input("Enter the BMI Index:"))
    if (BMI<18.5):
        print("Underweighted")
        message="underweighted"
    elif (BMI<24.9):
        print("Normal")
        message="Normal"
    elif(BMI<29.9):
        print("Overweight")
        message="Overweight"
    else:
        print("Very Overweighted")
        message="Very Overweighted"
    return message

# %%
message=BMI()
# Out:
# Enter the BMI Index: 34
# Very Overweighted

# %%
message
# Out:
# 'Very Overweighted'

# %%
#Non - Parameterized Function - Method 7

# %%
def BMI():

# %%
#Parameterized Function or Arguments - Method 8 - Addition

# %%
def Addition(num1,num2):
    Add=(num1+num2)
    return Add

# %%
Addition(5,4)
# Out:
# 9

# %%
#Subtraction

# %%
def Sub(num1,num2):
    Sub=(num1-num2)
    return Sub

# %%
Sub(6,2)
# Out:
# 4
