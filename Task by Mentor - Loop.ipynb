# %%
fields = input("Enter the Field: ").split(", ")
# Out:
# Enter the Field:  -Your Name-, -Your Age-, -Your Profession-

# %%
for field in fields:
    print(field)
# Out:
# -Your Name-
# -Your Age-
# -Your Profession-
