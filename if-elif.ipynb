# %%
if():
    print()
elif():
    print()
elif():
    print()
else:
    print()

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 65

# %%
if(age<18):
    print("Children")
elif(age<35):
    print("Adult")
elif(age<59):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Senior Citizen
