# %%
num=int(input("Enter the Number:"))
# Out:
# Enter the Number: 3

# %%
if((num%2)==0):
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Odd Number

# %%
num=int(input("Enter the Number:"))
# Out:
# Enter the Number: 3

# %%
if((num%2)==1):
    print("Odd Number")
else:
    print("Even Number")
# Out:
# Odd Number
