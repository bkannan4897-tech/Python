# %%
#1.Find the error in the following Python code:

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b):
    add_numbers = a + b
    return add_numbers #In the def add_numbers(a,b) and add_numbers = a+b both are okay, but in call the function the numbers should mention in 
    #call like add_numbers(5,6)

# %%
add_numbers(5, 6)
# Out:
# 11

# %%
#4.Identify the bug in the following Python code:

numbers = [1, 2, 3, 4]
print (numbers[1]) #In the list of numbers we should calculate [1 as 0, 2 as 1, 3 as 2, 4 as 3]. Beyond the 4 wil be error
# Out:
# 2

# %%
#5.Find the error in the following Python code:
print("Hello World!")
# Out:
# Hello World!

# %%
#6.Find the error in the following Python code:
def Division():
    Division = 5 / 2
    return Division

# %%
Division()
# Out:
# 2.5

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
name ="Alice"
print("name = " + name + ", age = " + str(age)) #In the age=25 number means variable, so str(age) - means it will be string
# Out:
# name = Alice, age = 25

# %%
#8.Find the error
for i in range(1, 10, 1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#9. Find the error in the following Python code:
if (age<5):
    print("age is 5")
else:
    print("age is below 5")
# Out:
# age is below 5

# %%
age=int(input("Enter the age"))
# Out:
# Enter the age 5

# %%
#10. Identify the error in the following function definition:

def greet():
    print("Hello")

# %%
greet()
# Out:
# Hello
